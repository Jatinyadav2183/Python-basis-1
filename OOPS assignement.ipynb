# %% [markdown]
# # OOPS ASSIGNEMENT

# %% [markdown]
# ### NAME : JATIN YADAV
# ### EMAIL : JATINYADAV2183@GMAIL.COM
# ### GITHUB LINK :

# %% [markdown]
# ## ***THEORITICAL QUESTION***

# %% [markdown]
# 1. **What is Object Oriented Programming(OOP)?**
#
#    Object-Oriented Programming (OOP) is a programming paradigm that organizes code into objects, which are instances of classes. These objects encapsulate data (attributes) and behavior (methods), making the code modular, reusable, and easier to manage.
#
#     **Key Concepts of OOP:**
#
#     Class – A blueprint for creating objects.
#
#     Object – An instance of a class with its own attributes and behavior.
#
#     Encapsulation – Hiding the internal state of an object and restricting access to it.
#
#     Abstraction – Hiding complex implementation details and exposing only essential features.
#
#     Inheritance – Allowing a class to derive properties and behavior from another class.
#
#     Polymorphism – Enabling a single interface to represent different data types or methods.
#
#     **Advantages of OOP:**
#
#     Enhances code reusability through inheritance.
#
#     Improves code maintainability and scalability.
#
#     Supports modular and structured programming.
#
#     Promotes data security through encapsulation.

# %% [markdown]
# 2. **What is a class in OOP?**
#
#     A class in Object-Oriented Programming (OOP) is a blueprint or template for creating objects. It defines the attributes (data) and methods (functions) that objects of the class will have.
#
#     **Key Features of a Class:**
#
#    Defines properties (also called attributes or instance variables).
#
#    Defines behaviors (methods or functions that operate on the attributes).
#
#    Allows object creation (instances of the class).

# %% [markdown]
# 3. **What is an object in OOP?**
#
#    An object in Object-Oriented Programming (OOP) is an instance of a class. It represents a real-world entity that has attributes (data) and behaviors (methods/functions).
#
#     **Key Characteristics of an Object:**
#
#    Identity – Each object is unique and has its own memory address.
#
#    State (Attributes) – Represents the data stored in an object.
#
#    Behavior (Methods) – Defines what actions the object can perform.

# %% [markdown]
# 4. **What is the difference between abstraction and encapsulation?**
#
# ![image.png](attachment:fd26b2b9-4c16-446a-be51-8a176f96ee43.png)

# %% [markdown]
# 5. **What are dunder methods in Python?**
#
#     Dunder methods (short for "Double Under" methods) are special methods in Python that begin and end with double underscores (__). They are also called magic methods because they allow objects to behave like built-in types and enable operator overloading.
#
#    **Purpose of Dunder Methods**
#
#     Control object creation and initialization (e.g., __init__, __new__).
#
#     Enable operator overloading (e.g., __add__, __sub__).
#
#     Define how objects are represented (e.g., __str__, __repr__).
#
#     Support iteration and indexing (e.g., __iter__, __getitem__).

# %% [markdown]
# 6. **Explain the concept of inheritance in OOP?**
#
#    Inheritance is one of the key principles of Object-Oriented Programming (OOP). It allows a class (called the child or subclass) to inherit properties and methods from another class (called the parent or superclass). This provides a way to create new classes based on existing ones, promoting code reuse and making the program easier to maintain.
#
#    **Key Concepts of Inheritance:**
#
#     1. Parent (Superclass): The class whose properties and methods are inherited by another class.
#
#     2. Child (Subclass): The class that inherits properties and methods from the parent class. The subclass can also have its own unique properties and methods.
#
#     3. "is-a" Relationship: The subclass is considered a specialized version of the parent class. For example, if you have a parent class Animal, and a subclass Dog, the subclass Dog "is a" type of Animal.
#
#     4. Method Overriding: The subclass can redefine (or override) a method inherited from the parent class to provide its own specific implementation.
#
#     5. Accessing Parent Methods/Properties: The child class can call methods or access properties from the parent class using super or similar keywords in some languages.

# %% [markdown]
# 7. **What is polymorphism in OOP?**
#
#    Polymorphism is another fundamental concept in Object-Oriented Programming (OOP), and it allows objects of different classes to be treated as objects of a common superclass. The key idea behind polymorphism is that the same method or property can behave differently depending on the object that it is acting upon.
#
#     In simpler terms, polymorphism allows for different types of objects to be treated in the same way, even though they might have different implementations of the same method or property. This provides flexibility in code and helps to reduce the complexity of a system.

# %% [markdown]
# 8. **How is encapsulation achieved in Python?**
#
#    In Python, encapsulation is one of the fundamental principles of Object-Oriented Programming (OOP) that refers to the bundling of data (attributes) and methods (functions) that operate on the data into a single unit, typically a class. Encapsulation helps restrict direct access to some of the object's components, which can prevent accidental modification of data and promote data security and integrity.
#
#     In Python, encapsulation is achieved through access modifiers (or visibility modifiers), which control how the attributes and methods of a class are accessed from outside the class.
#
#    **Benefits of Encapsulation:**
#
#     Data Protection: By restricting direct access to an object's internal state, encapsulation protects its integrity.
#
#     Flexibility: The implementation of the class can be changed without affecting external code that relies on the class.
#
#     Code Readability and Maintainability: Encapsulation helps to keep the internal workings of the class hidden, making the code cleaner and more modular.
#
#     Controlled Access: By providing public methods (getters and setters), you can control how an object's data is accessed or modified.

# %% [markdown]
# 9. **What is a constructor in Python?**
#
#     In Python, a constructor is a special method used to initialize an object's state when it is created. The constructor is automatically called when an instance of a class is created. It is typically used to set initial values for the object's attributes.
#
#     In Python, the constructor is defined by the method __init__(), which is a built-in method in Python's object-oriented system.

# %% [markdown]
# 10. **What are class and static methods in Python**
#
#     In Python, class methods and static methods are two types of methods that belong to the class rather than to instances of the class. These methods are used in specific situations where you need to interact with the class itself, rather than with instance objects.
#
#     **Class Method:**
#
#     A class method is a method that takes the class as its first argument, not an instance of the class. It is used to operate on class-level attributes (shared among all instances of the class) rather than instance-level attributes (specific to each object).
#
#     Class methods are defined using the @classmethod decorator.
#
#     **Static Method:**
#
#     A static method is a method that doesn't operate on either the instance (self) or the class (cls). It doesn't take any special first argument. Static methods are used when you want to perform some utility function or helper method that doesn't need access to the class or instance attributes.
#
#     Static methods are defined using the @staticmethod decorator.

# %% [markdown]
# 11. **What is method overloading in Python?**
#
#     Method overloading in Python refers to the ability to define multiple methods with the same name but with different parameter lists. However, Python does not support traditional method overloading in the way that languages like Java or C++ do. In Python, if you define multiple methods with the same name, the last one defined will overwrite the previous ones.
#
#     That said, Python allows a form of "overloading" by using default arguments, variable-length arguments, or custom logic within a method to handle different numbers or types of parameters.

# %% [markdown]
# 12. **What is method overriding in OOP?**
#
#     Method overriding in Object-Oriented Programming (OOP) refers to the ability of a subclass to provide a specific implementation of a method that is already defined in its superclass. When a subclass defines a method with the same name, same parameters, and same return type as a method in the superclass, it "overrides" the superclass's method.
#
#     Method overriding allows subclasses to alter or extend the behavior of inherited methods to suit their specific needs.

# %% [markdown]
# 13. **What is a property decorator in Python?**
#
#     In Python, the @property decorator is used to define a method as a property. It allows you to define a method that can be accessed like an attribute (i.e., without using parentheses), but still retain the behavior of a method. This is particularly useful when you want to control access to an attribute, either by calculating its value on the fly or by applying validation logic.

# %% [markdown]
# 14. **Why is polymorphism important in OOP?**
#
#     Polymorphism is one of the core principles of Object-Oriented Programming (OOP), alongside encapsulation, inheritance, and abstraction. It allows objects of different classes to be treated as objects of a common superclass, typically through a common interface. Polymorphism is crucial for creating flexible, maintainable, and extensible code. Here's why it's so important in OOP:
#
#     Code Reusability
#
#     Flexibility and Extensibility
#
#     Simplifies Code Maintenance
#
#     Improves Readability and Clarity
#
#     Enables Polymorphic Behavior in Collections
#
#     Reduces Complexity

# %% [markdown]
# 15. **What is an abstract class in Python?**
#
#     An abstract class in Python is a class that cannot be instantiated directly. Instead, it serves as a blueprint for other classes. Abstract classes allow you to define methods that must be created within any child classes built from the abstract class. They can also define methods with or without implementations.
#
#     Abstract classes are part of the Abstract Base Class (ABC) module in Python, which provides the foundation for defining abstract classes and enforcing that certain methods are implemented by subclasses.

# %% [markdown]
# 16. **What are the advantages of OOP?**
#
#     Object-Oriented Programming (OOP) offers several advantages that make it a popular paradigm for building complex software systems. Below are the key benefits of OOP:
#
#     1. **Modularity:**
#
#         Encapsulation: OOP encourages breaking down complex systems into smaller, manageable units called objects. These objects represent real-world entities and encapsulate both data (attributes) and behavior (methods).
#
#         Each object functions independently, and the interaction between objects is well-defined. This modular structure makes it easier to design, develop, and maintain software.
#
#     2. **Reusability:**
#
#         Inheritance allows classes to inherit properties and behaviors from other classes, promoting the reuse of code. You can extend or modify the behavior of a class without having to rewrite it completely.
#
#          Code reuse is enhanced through inheritance and polymorphism, which reduce redundancy and increase the maintainability of code.

# %% [markdown]
# 17. **What is the difference between a class variable and an instance variable?**
#
#     ![image.png](attachment:14f9e6b6-3412-44dc-ba21-1dd8f81e6cb5.png)

# %% [markdown]
# 18. **What is multiple inheritance in Python?**
#
#     Multiple inheritance in Python refers to the concept where a class can inherit from more than one class, allowing it to inherit methods and attributes from multiple parent classes. This allows for greater flexibility in the design of a class by combining the functionality of multiple base classes.
#
#     A class can inherit from more than one class, gaining access to the methods and attributes of all its parent classes.
#
#     It allows a subclass to combine the behavior of multiple parent classes.
#
#     It can lead to complex class hierarchies, which might cause ambiguity if methods or attributes with the same name exist in multiple parent classes.

# %% [markdown]
# 19. **Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?**
#
#      **__str__ Method:**
#
#     The __str__ method is meant to provide a human-readable string representation of an object, i.e., a string that is easy to understand when the object is printed or displayed.
#
#      It is used by print() and str() functions.
#
#      Its main purpose is to give a user-friendly description of the object.
#
#      If the __str__ method is not defined, Python will fall back to the default __repr__ method if it exists.
#
#
#     **__repr__ Method:**
#
#         The __repr__ method is meant to provide a formal string representation of the object, i.e., a string that can ideally be used to recreate the object. It's used for debugging and development.
#
#         It is used by the repr() function and is also invoked when you access an object in the interpreter or use it in a list or dictionary.
#
#         The goal of __repr__ is to provide a more unambiguous and technical representation of the object, often including details about the class and attributes.
#
#         If you don't define __str__, Python will use __repr__ as the fallback for string conversions.

# %% [markdown]
# 20. **What is the significance of the ‘super()’ function in Python?**
#
#     The super() function in Python is a built-in function that allows you to call methods from a parent (or superclass) in a child (or subclass) class. It's commonly used in inheritance to invoke methods from a superclass, particularly in cases where a subclass overrides methods and you still want to call the version of the method from the parent class.
#
#     Significance of super():
#
#     1. Access Parent Class Methods: It helps to call methods from a parent class inside a method of the subclass, even if the method is overridden in the subclass.
#
#     2. Avoid Explicit Parent Class Reference: It allows you to avoid directly referring to the parent class, making your code more maintainable and easier to manage (especially in cases of multiple inheritance).
#
#     3. Maintain Method Resolution Order (MRO): In cases of multiple inheritance, super() follows the Method Resolution Order (MRO), ensuring that the correct method from the right class is called. This allows for proper resolution in complex inheritance chains.

# %% [markdown]
# 21. **What is the significance of the __del__ method in Python?**
#
#     The __del__ method in Python is a special method, also known as a destructor, that is called when an object is about to be destroyed or garbage collected. It is used to perform cleanup operations before an object is destroyed, such as closing files, releasing external resources, or freeing up memory.

# %% [markdown]
# 22. **What is the difference between @staticmethod and @classmethod in Python?**
#
#     ![image.png](attachment:67aa2efe-7fbc-4dad-9070-c641106edcd8.png)

# %% [markdown]
# 23. **How does polymorphism work in Python with inheritance?**
#
#     In Python, polymorphism is one of the core concepts of Object-Oriented Programming (OOP), and it allows objects of different classes to be treated as objects of a common base class. The term polymorphism means "many forms," and in Python, it refers to the ability to use a single interface (method or property) for different data types.
#
#     In the context of inheritance, polymorphism allows a subclass to provide a different implementation of a method that is already defined in its parent class. This is known as method overriding.

# %% [markdown]
# 24. **What is method chaining in Python OOP?**
#
#     Method chaining in Python OOP refers to the practice of calling multiple methods on the same object in a single line of code, where each method returns the object itself (or another object). This allows you to perform multiple operations in a concise and readable manner, by chaining methods together, one after the other.

# %% [markdown]
# 25. **What is the purpose of the __call__ method in Python?**
#
#     In Python, the __call__ method is a special method that allows an instance of a class to be called like a regular function. In other words, it makes an object callable. When the __call__ method is defined in a class, instances of that class can be invoked using parentheses, just like you would call a function.
#
#     **Purpose of __call__ Method:**
#
#     The __call__ method is primarily used to:
#
#     1. Make objects callable: It allows objects to behave like functions. This can be useful in situations where an object needs to execute some logic when called, and the calling syntax is more convenient.
#
#     2. Encapsulate behavior: You can encapsulate behavior in a class, and then call an object just like a function to trigger that behavior.
#
#     3. Dynamic function-like objects: It allows an instance of a class to behave dynamically, providing a way to represent callable behavior while still using object-oriented programming techniques.
#
#     4. Decorators or callbacks: It can be useful in cases where you need to pass an object around as a callback or function-like object, such as in functional programming or event-driven programming.

# %% [markdown]
# ## ***PRACTICAL QUESTIONS***

# %% [markdown]
# 1. **Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".**

# %%
# Parent class
class Animal:
    def speak(self):
        print("Animal makes a sound")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Creating instances
animal = Animal()
dog = Dog()

# Calling the speak() method
animal.speak()  # Output: Animal makes a sound
dog.speak()     # Output: Bark!
# Out:
# Animal makes a sound
# Bark!

# %% [markdown]
# 2. **Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.**

# %%
from abc import ABC, abstractmethod
import math

# Abstract class Shape
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Derived class Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return math.pi * self.radius ** 2

# Derived class Rectangle
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height

# Creating instances
circle = Circle(5)
rectangle = Rectangle(4, 6)

# Calling area() method on instances
print(f"Area of Circle: {circle.area():.2f}")   # Area of Circle: 78.54
print(f"Area of Rectangle: {rectangle.area()}")  # Area of Rectangle: 24
# Out:
# Area of Circle: 78.54
# Area of Rectangle: 24

# %% [markdown]
# 3. **Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.**

# %%
# Base class: Vehicle
class Vehicle:
    def __init__(self, type_of_vehicle):
        self.type = type_of_vehicle
    
    def display_type(self):
        print(f"This is a {self.type} vehicle.")

# Derived class: Car (inherits from Vehicle)
class Car(Vehicle):
    def __init__(self, type_of_vehicle, brand):
        super().__init__(type_of_vehicle)  # Call the parent class's constructor
        self.brand = brand
    
    def display_info(self):
        print(f"This is a {self.brand} car of type {self.type}.")

# Derived class: ElectricCar (inherits from Car)
class ElectricCar(Car):
    def __init__(self, type_of_vehicle, brand, battery_capacity):
        super().__init__(type_of_vehicle, brand)  # Call the parent class's constructor
        self.battery_capacity = battery_capacity
    
    def display_battery_info(self):
        print(f"The {self.brand} electric car has a battery capacity of {self.battery_capacity} kWh.")

# Creating instances
vehicle = Vehicle("General")
car = Car("Car", "Toyota")
electric_car = ElectricCar("Electric Car", "Tesla", 100)

# Calling methods on instances
vehicle.display_type()  # Output: This is a General vehicle.
car.display_info()      # Output: This is a Toyota car of type Car.
electric_car.display_info()  # Output: This is a Tesla car of type Electric Car.
electric_car.display_battery_info()  # Output: The Tesla electric car has a battery capacity of 100 kWh.
# Out:
# This is a General vehicle.
# This is a Toyota car of type Car.
# This is a Tesla car of type Electric Car.
# The Tesla electric car has a battery capacity of 100 kWh.

# %% [markdown]
# 4.  **Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.**

# %%
# Base class: Vehicle
class Vehicle:
    def __init__(self, type_of_vehicle):
        self.type = type_of_vehicle  # Attribute to store vehicle type
    
    def display_type(self):
        print(f"This is a {self.type} vehicle.")

# Derived class: Car (inherits from Vehicle)
class Car(Vehicle):
    def __init__(self, type_of_vehicle, brand):
        super().__init__(type_of_vehicle)  # Initialize the parent class (Vehicle)
        self.brand = brand  # Additional attribute for the brand of the car
    
    def display_info(self):
        print(f"This is a {self.brand} car of type {self.type}.")

# Derived class: ElectricCar (inherits from Car)
class ElectricCar(Car):
    def __init__(self, type_of_vehicle, brand, battery_capacity):
        super().__init__(type_of_vehicle, brand)  # Initialize the parent class (Car)
        self.battery_capacity = battery_capacity  # Additional attribute for battery capacity
    
    def display_battery_info(self):
        print(f"The {self.brand} electric car has a battery capacity of {self.battery_capacity} kWh.")

# Creating instances
vehicle = Vehicle("General")
car = Car("Car", "Toyota")
electric_car = ElectricCar("Electric Car", "Tesla", 100)

# Calling methods on instances
vehicle.display_type()  # Output: This is a General vehicle.
car.display_info()      # Output: This is a Toyota car of type Car.
electric_car.display_info()  # Output: This is a Tesla car of type Electric Car.
electric_car.display_battery_info()  # Output: The Tesla electric car has a battery capacity of 100 kWh.
# Out:
# This is a General vehicle.
# This is a Toyota car of type Car.
# This is a Tesla car of type Electric Car.
# The Tesla electric car has a battery capacity of 100 kWh.

# %% [markdown]
# 5. **Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.**

# %%
class BankAccount:
    def __init__(self, initial_balance=0):
        # Private attribute
        self.__balance = initial_balance
    
    # Method to deposit money into the account
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount}. New balance: ${self.__balance}")
        else:
            print("Deposit amount must be positive.")
    
    # Method to withdraw money from the account
    def withdraw(self, amount):
        if amount <= 0:
            print("Withdrawal amount must be positive.")
        elif amount > self.__balance:
            print("Insufficient funds.")
        else:
            self.__balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.__balance}")
    
    # Method to check the balance
    def check_balance(self):
        print(f"Current balance: ${self.__balance}")

# Creating an instance of BankAccount
account = BankAccount(1000)

# Checking initial balance
account.check_balance()  # Output: Current balance: $1000

# Depositing money
account.deposit(500)  # Output: Deposited $500. New balance: $1500

# Withdrawing money
account.withdraw(200)  # Output: Withdrew $200. New balance: $1300

# Trying to withdraw more than balance
account.withdraw(2000)  # Output: Insufficient funds.

# Checking balance after transactions
account.check_balance()  # Output: Current balance: $1300
# Out:
# Current balance: $1000
# Deposited $500. New balance: $1500
# Withdrew $200. New balance: $1300
# Insufficient funds.
# Current balance: $1300

# %% [markdown]
# 6. **Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().**

# %%
# Base class: Instrument
class Instrument:
    def play(self):
        print("The instrument is playing.")

# Derived class: Guitar (inherits from Instrument)
class Guitar(Instrument):
    def play(self):
        print("The guitar is strumming.")

# Derived class: Piano (inherits from Instrument)
class Piano(Instrument):
    def play(self):
        print("The piano is playing a melody.")

# Demonstrating runtime polymorphism

# Creating instances
instrument = Instrument()
guitar = Guitar()
piano = Piano()

# Calling the play() method on different objects
instrument.play()  # Output: The instrument is playing.
guitar.play()      # Output: The guitar is strumming.
piano.play()       # Output: The piano is playing a melody.

# Storing derived class objects in base class reference to demonstrate polymorphism
instrument1 = Guitar()  # Base class reference holding derived class object
instrument2 = Piano()   # Base class reference holding derived class object

# Calling the play() method (this demonstrates polymorphism)
instrument1.play()  # Output: The guitar is strumming.
instrument2.play()  # Output: The piano is playing a melody.
# Out:
# The instrument is playing.
# The guitar is strumming.
# The piano is playing a melody.
# The guitar is strumming.
# The piano is playing a melody.

# %% [markdown]
# 7. **Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.**

# %%
class MathOperations:
    # Class method to add two numbers
    @classmethod
    def add_numbers(cls, num1, num2):
        return num1 + num2
    
    # Static method to subtract two numbers
    @staticmethod
    def subtract_numbers(num1, num2):
        return num1 - num2

# Using the class method to add numbers
result_add = MathOperations.add_numbers(10, 5)
print(f"Addition result: {result_add}")  # Output: Addition result: 15

# Using the static method to subtract numbers
result_subtract = MathOperations.subtract_numbers(10, 5)
print(f"Subtraction result: {result_subtract}")  # Output: Subtraction result: 5
# Out:
# Addition result: 15
# Subtraction result: 5

# %% [markdown]
# 8. **Implement a class Person with a class method to count the total number of persons created.**

# %%
class Person:
    # Class variable to keep track of total persons created
    total_persons = 0
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
        # Increment the class variable every time a new person is created
        Person.total_persons += 1
    
    # Class method to return the total number of persons created
    @classmethod
    def get_total_persons(cls):
        return cls.total_persons

# Creating instances of Person
person1 = Person("Alice", 30)
person2 = Person("Bob", 25)
person3 = Person("Charlie", 35)

# Getting the total number of persons created using the class method
total = Person.get_total_persons()
print(f"Total number of persons created: {total}")  # Output: Total number of persons created: 3
# Out:
# Total number of persons created: 3

# %% [markdown]
# 9. **Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".**

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        # Initializing the numerator and denominator
        self.numerator = numerator
        self.denominator = denominator
    
    # Override the __str__ method to display the fraction in "numerator/denominator" format
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Creating instances of Fraction
fraction1 = Fraction(3, 4)
fraction2 = Fraction(5, 6)

# Printing the fractions
print(fraction1)  # Output: 3/4
print(fraction2)  # Output: 5/6
# Out:
# 3/4
# 5/6

# %% [markdown]
# 10. **Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.**

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    # Overloading the + operator using __add__ method
    def __add__(self, other):
        if isinstance(other, Vector):
            # Add the corresponding components of the vectors
            return Vector(self.x + other.x, self.y + other.y)
        else:
            raise TypeError("Operand must be an instance of Vector")

    # Method to display the vector in (x, y) format
    def __str__(self):
        return f"({self.x}, {self.y})"

# Creating instances of Vector
vector1 = Vector(2, 3)
vector2 = Vector(4, 5)

# Adding two vectors
result_vector = vector1 + vector2

# Printing the result
print(f"Vector1: {vector1}")        # Output: (2, 3)
print(f"Vector2: {vector2}")        # Output: (4, 5)
print(f"Result of addition: {result_vector}")  # Output: (6, 8)
# Out:
# Vector1: (2, 3)
# Vector2: (4, 5)
# Result of addition: (6, 8)

# %% [markdown]
# 11. **Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old.**

# %%
class Person:
    def __init__(self, name, age):
        # Initializing the name and age attributes
        self.name = name
        self.age = age
    
    def greet(self):
        # Printing the greeting message
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Creating an instance of the Person class
person1 = Person("Alice", 30)

# Calling the greet() method
person1.greet()  # Output: Hello, my name is Alice and I am 30 years old.
# Out:
# Hello, my name is Alice and I am 30 years old.

# %% [markdown]
# 12. **Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.**

# %%
class Student:
    def __init__(self, name, grades):
        # Initializing the name and grades attributes
        self.name = name
        self.grades = grades
    
    def average_grade(self):
        # Calculating the average of the grades
        if len(self.grades) > 0:
            return sum(self.grades) / len(self.grades)
        else:
            return 0  # Return 0 if there are no grades

# Creating an instance of the Student class
student1 = Student("Alice", [90, 85, 88, 92, 95])

# Calling the average_grade() method
average = student1.average_grade()
print(f"{student1.name}'s average grade is: {average:.2f}")  # Output: Alice's average grade is: 90.00
# Out:
# Alice's average grade is: 90.00

# %% [markdown]
# 13. **Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.**

# %%
class Rectangle:
    def __init__(self):
        # Initializing length and width to 0 (default values)
        self.length = 0
        self.width = 0
    
    def set_dimensions(self, length, width):
        # Setting the length and width of the rectangle
        self.length = length
        self.width = width
    
    def area(self):
        # Calculating the area of the rectangle
        return self.length * self.width

# Creating an instance of the Rectangle class
rectangle1 = Rectangle()

# Setting the dimensions using the set_dimensions() method
rectangle1.set_dimensions(5, 3)

# Calling the area() method to calculate the area
area_of_rectangle = rectangle1.area()
print(f"The area of the rectangle is: {area_of_rectangle}")  # Output: The area of the rectangle is: 15
# Out:
# The area of the rectangle is: 15

# %% [markdown]
# 14. **Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.**

# %%
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate
    
    def calculate_salary(self):
        # Calculate salary based on hours worked and hourly rate
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        # Initialize the base class (Employee) attributes
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus
    
    def calculate_salary(self):
        # Call the base class method and add the bonus
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

# Creating instances of Employee and Manager
employee1 = Employee("John", 40, 25)  # 40 hours at $25 per hour
manager1 = Manager("Alice", 40, 30, 500)  # 40 hours at $30 per hour + $500 bonus

# Calculating and printing salaries
employee_salary = employee1.calculate_salary()
manager_salary = manager1.calculate_salary()

print(f"Employee {employee1.name}'s salary: ${employee_salary}")  # Output: 1000
print(f"Manager {manager1.name}'s salary: ${manager_salary}")  # Output: 1700
# Out:
# Employee John's salary: $1000
# Manager Alice's salary: $1700

# %% [markdown]
# 15. **Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.**

# %%
class Product:
    def __init__(self, name, price, quantity):
        # Initializing the name, price, and quantity attributes
        self.name = name
        self.price = price
        self.quantity = quantity
    
    def total_price(self):
        # Calculating the total price by multiplying price and quantity
        return self.price * self.quantity

# Creating an instance of the Product class
product1 = Product("Laptop", 1000, 3)

# Calling the total_price() method to calculate the total price
total = product1.total_price()

# Printing the total price
print(f"The total price of {product1.name} is: ${total}")  # Output: The total price of Laptop is: $3000
# Out:
# The total price of Laptop is: $3000

# %% [markdown]
# 16. **Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.**

# %%
from abc import ABC, abstractmethod

# Abstract base class Animal
class Animal(ABC):
    
    @abstractmethod
    def sound(self):
        pass

# Derived class Cow
class Cow(Animal):
    
    def sound(self):
        return "Moo"

# Derived class Sheep
class Sheep(Animal):
    
    def sound(self):
        return "Baa"

# Creating instances of Cow and Sheep
cow = Cow()
sheep = Sheep()

# Calling the sound() method for each animal
print(f"The cow says: {cow.sound()}")  # Output: The cow says: Moo
print(f"The sheep says: {sheep.sound()}")  # Output: The sheep says: Baa
# Out:
# The cow says: Moo
# The sheep says: Baa

# %% [markdown]
# 17. **Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.**

# %%
class Book:
    def __init__(self, title, author, year_published):
        # Initializing the title, author, and year_published attributes
        self.title = title
        self.author = author
        self.year_published = year_published
    
    def get_book_info(self):
        # Returning a formatted string with the book's details
        return f"Title: {self.title}\nAuthor: {self.author}\nYear Published: {self.year_published}"

# Creating an instance of the Book class
book1 = Book("The Great Gatsby", "F. Scott Fitzgerald", 1925)

# Calling the get_book_info() method to get the book's details
book_info = book1.get_book_info()

# Printing the book's information
print(book_info)
# Out:
# Title: The Great Gatsby
# Author: F. Scott Fitzgerald
# Year Published: 1925

# %% [markdown]
# 18. **Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.**

# %%
# Base class House
class House:
    def __init__(self, address, price):
        # Initializing address and price attributes
        self.address = address
        self.price = price
    
    def get_info(self):
        # Returning the basic information about the house
        return f"Address: {self.address}\nPrice: ${self.price}"

# Derived class Mansion
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        # Initialize the base class (House) attributes
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms
    
    def get_info(self):
        # Call the base class method and add number_of_rooms information
        base_info = super().get_info()
        return f"{base_info}\nNumber of Rooms: {self.number_of_rooms}"

# Creating an instance of House
house1 = House("123 Main St", 250000)

# Creating an instance of Mansion
mansion1 = Mansion("456 Luxury Ave", 5000000, 15)

# Calling the get_info() method for both house and mansion
print("House Info:")
print(house1.get_info())  # Basic house information

print("\nMansion Info:")
print(mansion1.get_info())  # Mansion info with number of rooms
# Out:
# House Info:
# Address: 123 Main St
# Price: $250000
#
# Mansion Info:
# Address: 456 Luxury Ave
# Price: $5000000
# Number of Rooms: 15

# %% [markdown]
# # END
